# %% [markdown]
# # Document Classification using Scikit

# %% [markdown]
# # Pre-processing

# %%
import pandas as pd
import os
import re
from nltk.corpus import stopwords

# %%
#directory = "/Users/ilabuser/TF/tensorflow_Data/Text_full"
directory = "/home/praveen/Documents/Data/Text_full"

# %%
f_names = []

# %%
filenames = os.listdir(directory)
    
for file in filenames:
    f_name = os.path.join(directory, file)
    f_names.append(f_name)

# %%
data_corpus = {}

for f in filenames:
    f_name = os.path.join(directory, f)
    fi = open(f_name)
    data = fi.read().lower()
    data_corpus[f] = data

# %%
data_corpus['ap-3815.pdf.txt']
# Out:
# 'united states of america\nbefore the\nsecurities and exchange commission\nwashington, d.c. 20549\nadministrative proceedings rulings\nrelease no. 3815/april 29, 2016\nadministrative proceeding\nfile no. 3-17133\n\nin the matter of\ntexstar oil corporation, and\nbonamour, inc.\n\nstay order\n\ntoday, the parties filed a joint motion to stay this proceeding based upon their agreement\nin principle to a settlement that will resolve the proceeding on all major terms.\nfor good cause shown, it is ordered that the joint motion is granted, and the\nproceeding is stayed, subject to compliance with rule of practice 161(c)(2), 17 c.f.r.\n\xc2\xa7 201.161(c)(2), requiring that this office be notified promptly if any of the requirements of the\nrule are not met.\n_______________________________\njason s. patil\nadministrative law judge\n\n\x0c'

# %%
data = pd.DataFrame.from_dict(data_corpus,orient='index')

# %%
data = data.reset_index()
data.columns = ['file_name','text']

# %%
data
# Out:
#                     file_name  \
# 0             ap-4081.pdf.txt
# 1             ap-3948.pdf.txt
# 2            id744cff.pdf.txt
# 3             ap-3748.pdf.txt
# 4            33-10168.pdf.txt
# 5            34-68988.pdf.txt
# 6            33-10094.pdf.txt
# 7             ap-3777.pdf.txt
# 8            34-75165.pdf.txt
# 9            id302cff.pdf.txt
# 10            ap-3776.pdf.txt
# 11           34-53041.pdf.txt
# 12           monyquiz.pdf.txt
# 13           34-77739.pdf.txt
# 14           33-10228.pdf.txt
# 15           34-77423.pdf.txt
# 16           34-77250.pdf.txt
# 17           34-77013.pdf.txt
# 18           34-70082.pdf.txt
# 19           34-77288.pdf.txt
# 20            ap-4044.pdf.txt
# 21               sgtd.pdf.txt
# 22          id1047cff.pdf.txt
# 23           33-10225.pdf.txt
# 24            ap-3492.pdf.txt
# 25           34-72247.pdf.txt
# 26           34-72505.pdf.txt
# 27            ia-4455.pdf.txt
# 28            ap-4000.pdf.txt
# 29       34-69604-pdp.pdf.txt
# ...                       ...
# 3628          ap-4171.pdf.txt
# 3629          ap-3618.pdf.txt
# 3630         34-78184.pdf.txt
# 3631       34-79042-o.pdf.txt
# 3632        comp23658.pdf.txt
# 3633          ap-4303.pdf.txt
# 3634         34-77563.pdf.txt
# 3635         34-77648.pdf.txt
# 3636         34-76722.pdf.txt
# 3637         id328bpm.pdf.txt
# 3638         33-10158.pdf.txt
# 3639         34-78495.pdf.txt
# 3640         34-78560.pdf.txt
# 3641          33-9354.pdf.txt
# 3642         34-78148.pdf.txt
# 3643         34-77870.pdf.txt
# 3644         id940jeg.pdf.txt
# 3645    3-11498-order.pdf.txt
# 3646         34-78365.pdf.txt
# 3647         34-78708.pdf.txt
# 3648  comp-pr2016-170.pdf.txt
# 3649         34-59930.pdf.txt
# 3650          ap-3577.pdf.txt
# 3651         34-76743.pdf.txt
# 3652         34-77300.pdf.txt
# 3653         34-67824.pdf.txt
# 3654          ap-3589.pdf.txt
# 3655         34-59870.pdf.txt
# 3656         33-10002.pdf.txt
# 3657          ap-4145.pdf.txt
#
#                                                    text
# 0     united states of america\nbefore the\nsecuriti...
# 1     united states of america\nbefore the\nsecuriti...
# 2     initial decision release no. 744\nadministrati...
# 3     united states of america\nbefore the\nsecuriti...
# 4     united states of america\nbefore the\nsecuriti...
# 5     united states of america\nbefore the\nsecuriti...
# 6     united states of america\nbefore the\nsecuriti...
# 7     united states of america\nbefore the\nsecuriti...
# 8     securities and exchange commission\nrelease no...
# 9     initial decision release no. 302\nadministrati...
# 10    united states of america\nbefore the\nsecuriti...
# 11    united states of america\nbefore the\nsecuriti...
# 12    test your\n\nmoney$ marts\n\nfacts on saving a...
# 13    united states of america\nbefore the\nsecuriti...
# 14    united states of america\nbefore the\nsecuriti...
# 15    united states of america\nbefore the\nsecuriti...
# 16    united states of america\nbefore the\nsecuriti...
# 17    united states of america\nbefore the\nsecuriti...
# 18    united states of america\nbefore the\nsecuriti...
# 19    united states of america\nbefore the\nsecuriti...
# 20    united states of america\nbefore the\nsecuriti...
# 21    2016 louisiana state government\ntelephone di...
# 22    initial decision release no. 1047\nadministrat...
# 23    united states of america\nbefore the\nsecuriti...
# 24    united states of america\nbefore the\nsecuriti...
# 25    united states of america\nbefore the\nsecuriti...
# 26    united states of america\nbefore the\nsecuriti...
# 27    united states of america\nbefore the\nsecuriti...
# 28    united states of america\nbefore the\nsecuriti...
# 29    united states of america\nbefore the\nsecuriti...
# ...                                                 ...
# 3628  united states of america\nbefore the\nsecuriti...
# 3629  united states of america\nbefore the\nsecuriti...
# 3630  united states of america\nbefore the\nsecuriti...
# 3631  united states of america\nbefore the\nsecuriti...
# 3632  case 1:16-cv-24106-jal document 1 entered on f...
# 3633  united states of america\nbefore the\nsecuriti...
# 3634  united states of america\nbefore the\nsecuriti...
# 3635  united states of america\nbefore the\nsecuriti...
# 3636  united states of america\nbefore the\nsecuriti...
# 3637  initial decision release no. 328\nadministrati...
# 3638  united states of america\nbefore the\nsecuriti...
# 3639  united states of america\nbefore the\nsecuriti...
# 3640  united states of america\nbefore the\nsecuriti...
# 3641  securities and exchange commission\n17 cfr par...
# 3642  united states of america\nbefore the\nsecuriti...
# 3643  united states of america\nbefore the\nsecuriti...
# 3644  initial decision release no. 940\nadministrati...
# 3645  united states of america \n\nbefore the \n\nse...
# 3646  u.s. securities and exchange commission\nwashi...
# 3647  united states of america\nbefore the\nsecuriti...
# 3648  case 2:16-cv-06427 document 1 filed 08/26/16 p...
# 3649  united states of america \n\nbefore the\n\nsec...
# 3650  united states of america\nbefore the\nsecuriti...
# 3651  securities and exchange commission\n17 cfr par...
# 3652  united states of america\nbefore the\nsecuriti...
# 3653  united states of america\nbefore the\nsecuriti...
# 3654  united states of america\nbefore the\nsecuriti...
# 3655  united states of america \n\nbefore the \n\nse...
# 3656  united states of america\nbefore the\nsecuriti...
# 3657  united states of america\nbefore the\nsecuriti...
#
# [3658 rows x 2 columns]

# %%
def clean_text(raw_text):
    letters_only = re.sub("[^a-z]", " ", raw_text)
    words = letters_only.split()
    stops = set(stopwords.words("english"))
    meaningful_words = [w for w in words if not w in stops and len(w)>1]
    return( " ".join( meaningful_words ))

# %%
print stopwords.words("english")
# Out:
# [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u'your', u'yours', u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u'her', u'hers', u'herself', u'it', u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', u'who', u'whom', u'this', u'that', u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', u'both', u'each', u'few', u'more', u'most', u'other', u'some', u'such', u'no', u'nor', u'not', u'only', u'own', u'same', u'so', u'than', u'too', u'very', u's', u't', u'can', u'will', u'just', u'don', u'should', u'now', u'd', u'll', u'm', u'o', u're', u've', u'y', u'ain', u'aren', u'couldn', u'didn', u'doesn', u'hadn', u'hasn', u'haven', u'isn', u'ma', u'mightn', u'mustn', u'needn', u'shan', u'shouldn', u'wasn', u'weren', u'won', u'wouldn']

# %%
data['text_clean'] = data['text'].apply(clean_text)

# %%
data['text'][0]
# Out:
# 'united states of america\nbefore the\nsecurities and exchange commission\nwashington, d.c. 20549\nadministrative proceedings rulings\nrelease no. 4081/august 22, 2016\nadministrative proceeding\nfile no. 3-17376\n\nin the matter of\neastland financial corp.,\ngranite cliffs, incorporated, and\ngreater asia realty holdings, ltd.\n\norder postponing hearing and\nscheduling prehearing\nconference\n\non august 10, 2016, the securities and exchange commission issued an order instituting\nproceedings (oip) against respondents pursuant to section 12(j) of the securities exchange act\nof 1934. the hearing is scheduled to commence on august 29, 2016.\non august 18, 2016, the division of enforcement filed a declaration of service\nestablishing that respondents were served with the oip by u.s. postal service express mail on\naugust 15, 2016, in accordance with rule of practice 141(a)(2)(ii), 17 c.f.r. \xc2\xa7 201.141(a)(ii).\nrespondents\xe2\x80\x99 answers are due by august 29, 2016. oip at 3; 17 c.f.r. \xc2\xa7\xc2\xa7 201.160(a)-(b),\n.220(b).\ni order that the hearing scheduled for august 29, 2016, is postponed and a\ntelephonic prehearing conference shall be held at 3:30 p.m. edt on september 12, 2016. any\nrespondent that fails to timely file an answer, appear at the prehearing conference, or otherwise\ndefend the proceeding will be deemed in default and the registration of its securities will be\nrevoked. oip at 3; 17 c.f.r. \xc2\xa7\xc2\xa7 201.155(a), .220(f), .221(f).\n\n_______________________________\njames e. grimes\nadministrative law judge\n\n\x0c'

# %%
data['text_clean'][0]
# Out:
# 'united states america securities exchange commission washington administrative proceedings rulings release august administrative proceeding file matter eastland financial corp granite cliffs incorporated greater asia realty holdings ltd order postponing hearing scheduling prehearing conference august securities exchange commission issued order instituting proceedings oip respondents pursuant section securities exchange act hearing scheduled commence august august division enforcement filed declaration service establishing respondents served oip postal service express mail august accordance rule practice ii ii respondents answers due august oip order hearing scheduled august postponed telephonic prehearing conference shall held edt september respondent fails timely file answer appear prehearing conference otherwise defend proceeding deemed default registration securities revoked oip james grimes administrative law judge'

# %% [markdown]
# # Creating TF-IDF

# %%
import sklearn as sk
import scipy as sc
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000)

# %%
train_data_features = vectorizer.fit_transform(data['text_clean'])

# %%
train_data_features
# Out:
# <3658x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1602635 stored elements in Compressed Sparse Row format>

# %%
train_data_features.get_shape()
# Out:
# (3658, 5000)

# %%
train_data_norm = sk.preprocessing.normalize(train_data_features,norm='l1')

# %%
train_data_np = train_data_norm.toarray()

# %%
sum(train_data_np[1])
# Out:
# 0.99999999999999956

# %%
vocab = vectorizer.get_feature_names()
print vocab
# Out:
# [u'aa', u'aaer', u'aaron', u'ab', u'aba', u'abcp', u'abetted', u'abetting', u'ability', u'able', u'abroad', u'abs', u'absence', u'absent', u'absolute', u'abuse', u'abuses', u'abusive', u'abx', u'ac', u'academic', u'accelerated', u'accept', u'acceptable', u'acceptance', u'accepted', u'accepting', u'access', u'accessed', u'accessible', u'accho', u'accommodate', u'accommodation', u'accompanied', u'accompanying', u'accomplish', u'accomplished', u'accord', u'accordance', u'according', u'accordingly', u'account', u'accountability', u'accountant', u'accountants', u'accounted', u'accountholder', u'accountholders', u'accounting', u'accounts', u'accredited', u'accrual', u'accrue', u'accrued', u'accumulated', u'accuracy', u'accurate', u'accurately', u'ach', u'achieve', u'achieved', u'achievement', u'achieving', u'acknowledge', u'acknowledged', u'acknowledges', u'acknowledgment', u'acquire', u'acquired', u'acquiring', u'acquisition', u'acquisitions', u'across', u'act', u'acted', u'acting', u'action', u'actions', u'active', u'actively', u'activities', u'activity', u'actor', u'actors', u'acts', u'actual', u'actually', u'ad', u'adams', u'add', u'added', u'adding', u'addition', u'additional', u'additionally', u'additions', u'address', u'addressed', u'addresses', u'addressing', u'adequacy', u'adequate', u'adequately', u'adhere', u'adjust', u'adjusted', u'adjustment', u'adjustments', u'admin', u'administer', u'administered', u'administering', u'administration', u'administrative', u'administrator', u'administrators', u'admission', u'admissions', u'admitted', u'admitting', u'adopt', u'adopted', u'adopting', u'adoption', u'adv', u'advance', u'advanced', u'advances', u'advantage', u'advantages', u'adverse', u'adversely', u'advertisement', u'advertisements', u'advertising', u'advice', u'advise', u'advised', u'adviser', u'advisers', u'advising', u'advisor', u'advisors', u'advisory', u'advocate', u'afc', u'aff', u'affairs', u'affect', u'affected', u'affecting', u'affiliate', u'affiliated', u'affiliates', u'affirmative', u'affirmed', u'afford', u'afforded', u'afr', u'africa', u'african', u'ag', u'age', u'agencies', u'agency', u'agenda', u'agent', u'agents', u'aggregate', u'aggregated', u'aggregating', u'aggregation', u'aggressive', u'ago', u'agree', u'agreed', u'agreeing', u'agreement', u'agreements', u'agrees', u'ai', u'aicpa', u'aid', u'aided', u'aiding', u'aids', u'aim', u'aimed', u'aims', u'air', u'airport', u'al', u'alabama', u'aladdin', u'alaska', u'albert', u'alert', u'alger', u'algorithm', u'align', u'aligned', u'alignment', u'alj', u'allegation', u'allegations', u'alleged', u'allegedly', u'alleges', u'alleging', u'allen', u'alliance', u'allocate', u'allocated', u'allocation', u'allocations', u'allow', u'allowance', u'allowances', u'allowed', u'allowing', u'allows', u'almost', u'alone', u'along', u'alpha', u'alphasector', u'already', u'also', u'alter', u'alternate', u'alternative', u'alternatively', u'alternatives', u'although', u'always', u'amend', u'amended', u'amending', u'amendment', u'amendments', u'america', u'american', u'ameriprise', u'amex', u'amicus', u'among', u'amortization', u'amortized', u'amount', u'amounted', u'amounts', u'amz', u'analyses', u'analysis', u'analyst', u'analysts', u'analytical', u'analyze', u'analyzed', u'analyzing', u'anc', u'ancillary', u'anddesist', u'anderson', u'andrew', u'angel', u'angeles', u'announced', u'announcement', u'annual', u'annualized', u'annually', u'annuities', u'annuity', u'anonymous', u'another', u'answer', u'answered', u'answers', u'anthony', u'anti', u'anticipate', u'anticipated', u'anticipates', u'anticipation', u'antifraud', u'anyone', u'anything', u'ap', u'api', u'app', u'apparent', u'appeal', u'appealed', u'appeals', u'appear', u'appearance', u'appeared', u'appearing', u'appears', u'appellant', u'appellants', u'appellate', u'appendix', u'applicability', u'applicable', u'applicant', u'applicants', u'application', u'applications', u'applied', u'applies', u'apply', u'applying', u'appoint',  ...

# %%
tf_idf_sum = np.sum(train_data_np, axis=0)
tf_idf_sum_vocab = pd.DataFrame(data=zip(vocab, tf_idf_sum),columns=['word','tf_idf_sum'])

# %%
tf_idf_sum_vocab.sort_values(by=['tf_idf_sum'],ascending=False)
# Out:
#                 word  tf_idf_sum
# 880       commission   44.259485
# 4115      securities   32.383551
# 1759        exchange   27.794489
# 73               act   25.976008
# 3191           order   24.395054
# 113   administrative   22.251917
# 3933      respondent   21.829830
# 2328             inc   19.825167
# 3641        pursuant   17.526223
# 2055            fund   16.596214
# 4106         section   16.528808
# 3934     respondents   15.968473
# 3140             oip   15.936158
# 2186         hearing   15.891593
# 3523      proceeding   15.566723
# 3524     proceedings   15.512453
# 4027            rule   14.842506
# 3377            plan   14.553958
# 2558           judge   13.790803
# 1924            file   13.741229
# 1469    distribution   13.287156
# 1247        decision   13.248583
# 3831         release   13.038717
# 3451      prehearing   12.821543
# 1483        division   12.224732
# 2619             law   12.148586
# 4102             sec   11.623358
# 981       conference   11.566034
# 4031         rulings   11.416039
# 2826             may   11.174153
# ...              ...         ...
# 1912             fia    0.014496
# 3987       revolving    0.014417
# 1174             csd    0.014192
# 2804          markit    0.013736
# 2259             ias    0.013555
# 4129            sefs    0.013544
# 4987              xs    0.013515
# 4513          takers    0.013268
# 4069            sbsd    0.012801
# 2073           gamma    0.012607
# 629          bunched    0.012525
# 3354              pf    0.012234
# 1491            docx    0.012130
# 368              asf    0.011767
# 447       authorised    0.011712
# 5               abcp    0.011626
# 3105          occupy    0.011564
# 2100           giver    0.011128
# 357              arp    0.011021
# 1334           depts    0.010912
# 3889      reproposal    0.010539
# 4288       soundness    0.010520
# 4436        subtitle    0.009947
# 2970           msbsp    0.009484
# 511              bds    0.008998
# 544              bhc    0.008540
# 3071        novation    0.006325
# 481      backloading    0.004382
# 948      compression    0.004267
# 4986              xr    0.004101
#
# [5000 rows x 2 columns]

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA 
pca = PCA(n_components=2)
pca_comp = pca.fit_transform(train_data_np)

# %%
pca_comp[:,0]
# Out:
# array([ 0.06598829,  0.02226494, -0.0043227 , ..., -0.03556187,
#        -0.01686188,  0.00571915])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(num=None, figsize=(8, 8), dpi=80, facecolor='w', edgecolor='k')
plt.plot(pca_comp[:,0],pca_comp[:,1],'bo')
plt.show()

# %% [markdown]
# # K-means

# %%
from sklearn.cluster import KMeans

# %%
KMeans_euc_model = KMeans(n_clusters=4).fit(train_data_norm)

# %%
KMeans_euc_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'copy_x': True,
#  'init': 'k-means++',
#  'max_iter': 300,
#  'n_clusters': 4,
#  'n_init': 10,
#  'n_jobs': 1,
#  'precompute_distances': 'auto',
#  'random_state': None,
#  'tol': 0.0001,
#  'verbose': 0}

# %%
np.bincount(KMeans_euc_model.labels_)
# Out:
# array([ 657,  531,  429, 2041])

# %%
KMeans_euc_model.cluster_centers_
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   8.06339343e-05, ...,
#           0.00000000e+00,   0.00000000e+00,   5.79570898e-05],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  1.06892185e-06,   0.00000000e+00,   1.42633011e-05, ...,
#           0.00000000e+00,   1.47504253e-05,   0.00000000e+00],
#        [  8.66880611e-05,   6.54592829e-05,   1.12181494e-04, ...,
#           1.41472024e-05,   3.60279396e-05,   6.09102878e-05]])

# %%
KMeans_euc_model.inertia_
# Out:
# 43.47195213720293

# %%
KMeans_model = []

for i in xrange(2,6):
    print "Running Kmeans with ",i," clusters"
    KMeans_model.append(KMeans(n_clusters=i).fit(train_data_norm))
# Out:
# Running Kmeans with  2  clusters
# Running Kmeans with  3  clusters
# Running Kmeans with  4  clusters
# Running Kmeans with  5  clusters

# %%
import pickle

with open("KMeans_models", "wb") as fp: 
    pickle.dump(KMeans_model, fp)
    
#with open("KMeans_models", "rb") as fp: 
    #KMeans_model = pickle.load(fp)

# %%
inertia = [i.inertia_ for i in KMeans_model]

plt.figure(num=None, figsize=(7, 4), dpi=80, facecolor='w', edgecolor='k')
plt.plot(np.array(xrange(len(KMeans_model))),np.array(inertia),linestyle='solid',linewidth=4, color='red')
plt.xlabel('Number of clusters',fontsize=14, color='blue')
plt.ylabel('Inertia',fontsize=14, color='blue')
plt.rcParams.update({'font.size': 16})
plt.tight_layout()
plt.show()

# %%
for i in xrange(len(KMeans_model)):
    print "Num of clusters: ",KMeans_model[i].n_clusters
    print "Num of docs in each cluster: ",np.bincount(KMeans_model[i].labels_)
    print "----------------------------------------------------------------------------------------------------------------"
# Out:
# Num of clusters:  2
# Num of docs in each cluster:  [2979  679]
# ----------------------------------------------------------------------------------------------------------------
# Num of clusters:  3
# Num of docs in each cluster:  [ 139 2851  668]
# ----------------------------------------------------------------------------------------------------------------
# Num of clusters:  4
# Num of docs in each cluster:  [2399  530  158  571]
# ----------------------------------------------------------------------------------------------------------------
# Num of clusters:  5
# Num of docs in each cluster:  [ 158  431  521  139 2409]
# ----------------------------------------------------------------------------------------------------------------

# %%
KMeans_model[13].cluster_centers_[KMeans_model[13].labels_].shape
# Out:
# (3676, 5000)

# %%
train_data_np.shape
# Out:
# (3658, 5000)

# %%
dist_doc_centroid = np.zeros(shape=(3676))

for i in xrange(train_data_np.shape[0]): 
    cluster_id = KMeans_model[13].labels_[i]
    dist_doc_centroid[i] = sc.spatial.distance.euclidean(train_data_np[i], 

                                                         
                                                         KMeans_model[13].cluster_centers_[cluster_id])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-52dc785d513b> in <module>()
#       2
#       3 for i in xrange(train_data_np.shape[0]):
# ----> 4     cluster_id = KMeans_model[13].labels_[i]
#       5     dist_doc_centroid[i] = sc.spatial.distance.euclidean(train_data_np[i],
#       6
#
# IndexError: list index out of range

# %%
dist_doc_centroid
# Out:
# array([ 0.09876156,  0.05046611,  0.17908945, ...,  0.09979327,
#         0.07940338,  0.06976781])

# %%
import pprint

def print_file_with_clusters(num_clusters):
    file_with_clusters = {}
    data['cluster'] = KMeans_model[num_clusters - 1].labels_
    
    for i in xrange(num_clusters):
        file_with_clusters[i] = list(data[data['cluster']==i]['file_name'].values[0:20])
    
    pprint.pprint(file_with_clusters)

# %%
print_file_with_clusters(4)
# Out:
# {0: ['ap-3651.pdf.txt',
#      'ap-3839.pdf.txt',
#      'ap-3620.pdf.txt',
#      'ap-3647.pdf.txt',
#      'ap-3856.pdf.txt',
#      'ap-4193.pdf.txt',
#      'ap-3848.pdf.txt',
#      'ap-3859.pdf.txt',
#      'ap-3718.pdf.txt',
#      'ap-3928.pdf.txt',
#      'ap-3648.pdf.txt',
#      'ap-4195.pdf.txt',
#      'ap-3938.pdf.txt',
#      'ap-4285.pdf.txt',
#      'ap-3757.pdf.txt',
#      'ap-4075.pdf.txt',
#      'ap-4076.pdf.txt',
#      'ap-3933.pdf.txt',
#      'ap-4170.pdf.txt',
#      'ap-3958.pdf.txt'],
#  1: ['34-68988.pdf.txt',
#      '34-53041.pdf.txt',
#      '34-70082.pdf.txt',
#      '34-72247.pdf.txt',
#      '34-72505.pdf.txt',
#      '34-69604-pdp.pdf.txt',
#      '34-60056a.pdf.txt',
#      '34-74231.pdf.txt',
#      '34-53453.pdf.txt',
#      '34-77497-pdp.pdf.txt',
#      '34-63143.pdf.txt',
#      '34-60310.pdf.txt',
#      '34-62936.pdf.txt',
#      '34-74993.pdf.txt',
#      '34-77131.pdf.txt',
#      '34-70151.pdf.txt',
#      '34-55598-pdp.pdf.txt',
#      '34-71825.pdf.txt',
#      '34-53432.pdf.txt',
#      '34-54838.pdf.txt'],
#  2: ['ap-4081.pdf.txt',
#      'ap-3948.pdf.txt',
#      'ap-3748.pdf.txt',
#      'ap-3777.pdf.txt',
#      'ap-3492.pdf.txt',
#      'ap-4000.pdf.txt',
#      'ap-4135.pdf.txt',
#      'ap-3455.pdf.txt',
#      'ap-3474.pdf.txt',
#      'ap-3871.pdf.txt',
#      'ap-3844.pdf.txt',
#      'ap-3985.pdf.txt',
#      'ap-3899.pdf.txt',
#      'ap-4092.pdf.txt',
#      'ap-3878.pdf.txt',
#      'ap-4266.pdf.txt',
#      'ap-3795.pdf.txt',
#      'ap-3633.pdf.txt',
#      'ap-4215.pdf.txt',
#      'ap-3491.pdf.txt'],
#  3: ['34-77423.pdf.txt',
#      '34-77250.pdf.txt',
#      '34-77013.pdf.txt',
#      '34-77514.pdf.txt',
#      '34-78072.pdf.txt',
#      '34-77667.pdf.txt',
#      '34-77377.pdf.txt',
#      '34-78493.pdf.txt',
#      '34-78336.pdf.txt',
#      '34-77515.pdf.txt',
#      '34-78257.pdf.txt',
#      '34-77655.pdf.txt',
#      '33-9695.pdf.txt',
#      '34-77987.pdf.txt',
#      '33-10045.pdf.txt',
#      '34-79104.pdf.txt',
#      '34-79033.pdf.txt',
#      '34-77616.pdf.txt',
#      '33-10047.pdf.txt',
#      '34-78399.pdf.txt']}

# %%
plt.figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')
plt.scatter(pca_comp[:,0],pca_comp[:,1],c=np.array(KMeans_model[3].labels_),s=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mixture Model

# %%
from sklearn import mixture
EM_model = mixture.GaussianMixture(n_components=5).fit(train_data_np)

# %%
EM_model.get_params
# Out:
# <bound method GaussianMixture.get_params of GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#         means_init=None, n_components=5, n_init=1, precisions_init=None,
#         random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)>

# %%
EM_model.covariances_.shape
# Out:
# (5, 5000, 5000)

# %%
EM_model.weights_
# Out:
# array([ 0.03799891,  0.15172225,  0.043193  ,  0.68644068,  0.08064516])

# %%
print EM_model.weights_(train_data_np[0])
print EM_model.predict_proba(train_data_np[100])
print EM_model.predict_proba(train_data_np[200])
print EM_model.predict_proba(train_data_np[300])
print EM_model.predict_proba(train_data_np[700])
print EM_model.predict_proba(train_data_np[2000])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-2ab1fed60e82> in <module>()
# ----> 1 print EM_model.weights_(train_data_np[0])
#       2 print EM_model.predict_proba(train_data_np[100])
#       3 print EM_model.predict_proba(train_data_np[200])
#       4 print EM_model.predict_proba(train_data_np[300])
#       5 print EM_model.predict_proba(train_data_np[700])
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import itertools

import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn import mixture

color_iter = itertools.cycle(['navy', 'c', 'cornflowerblue', 'gold',
                              'darkorange'])


def plot_results(X, Y_, means, covariances, index, title):
    splot = plt.subplot(2, 1, 1 + index)
    for i, (mean, covar, color) in enumerate(zip(
            means, covariances, color_iter)):
        v, w = linalg.eigh(covar)
        v = 2. * np.sqrt(2.) * np.sqrt(v)
        u = w[0] / linalg.norm(w[0])
        # as the DP will not use every component it has access to
        # unless it needs it, we shouldn't plot the redundant
        # components.
        if not np.any(Y_ == i):
            continue
        plt.scatter(X[Y_ == i, 0], X[Y_ == i, 1], .8, color=color)

        # Plot an ellipse to show the Gaussian component
        angle = np.arctan(u[1] / u[0])
        angle = 180. * angle / np.pi  # convert to degrees
        ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
        ell.set_clip_box(splot.bbox)
        ell.set_alpha(0.5)
        splot.add_artist(ell)

    plt.xlim(-9., 5.)
    plt.ylim(-3., 6.)
    plt.xticks(())
    plt.yticks(())
    plt.title(title)

# %%
plot_results(train_data_np, EM_model.predict(train_data_np), EM_model.means_, EM_model.covariances_, 0,
             'Gaussian Mixture')
# Out:
# /home/praveen/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:29: RuntimeWarning: invalid value encountered in double_scalars

# %%
plt.show()

# %% [markdown]
# # Creating test and train dataset

# %%
data_full = pd.DataFrame(train_data_np)

# %%
data_full.columns = vocab

# %%
data_full['_class_label_'] = np.array(KMeans_model[3].labels_)

# %%
train_data = data_full.sample(frac=0.8,random_state=200)
test_data = data_full.drop(train_data.index)

# %%
train_data.to_csv('train_data.csv', sep='\t', encoding='utf-8',index=False)
test_data.to_csv('test_data.csv', sep='\t', encoding='utf-8',index=False)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
train_rf = RandomForestClassifier(n_estimators=100).fit(train_data.drop('_class_label_', 1),train_data['_class_label_'])

# %%
output = train_rf.predict(test_data.drop('_class_label_', 1))

# %%
sk.metrics.accuracy_score(test_data['_class_label_'],output)

# %%
sk.metrics.confusion_matrix(test_data['_class_label_'],output)

# %%
np.bincount(test_data['_class_label_'])
